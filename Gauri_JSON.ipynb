# %%
record = {1160111:{"name":"Chocalate","price":55,"quantity":500,"exp_date":"22-05-2023"},
          1160112:{"name":"Maggiee","price":60,"quantity":10,"exp_date":"2012-2025"},
          1160113:{"name":"Coffee","price":120,"quantity":5,"exp_date":"22-08-2025"},
          1160114:{"name":"Sugar","price":80,"quantity":6,"exp_date":"2-07-2023"},
          1160115:{"name":"cadboury","price":200,"quantity":20,"exp_date":"22-05-2029"},
          1160116:{"name":"biscuit","price":50,"quantity":10,"exp_date":"11-09-2025"},
          1160117:{"name":"Water","price":40,"quantity":15,"exp_date":"16-05-2023"},
          1160118:{"name":"Colddrink","price":75,"quantity":5,"exp_date":"12-07-2026"},
          1160119:{"name":"Sanitizer","price":110,"quantity":6,"exp_date":"12-05-2030"},
          1160120:{"name":"Burger","price":125,"quantity":8,"exp_date":"30-10-2025"},
          1160121:{"name":"Pizza","price":300,"quantity":4,"exp_date":"19-05-2024"},
          1160122:{"name":"Tea","price":320,"quantity":7,"exp_date":"02-11-2026"},
          1160123:{"name":"sandwitch","price":100,"quantity":9,"exp_date":"29-05-2022"},
           1160124:{"name":"Lassi","price":30,"quantity":10,"exp_date":"08-05-2023"},
          1160125:{"name":"Cookies","price":55,"quantity":12,"exp_date":"06-04-2025"},
          1160126:{"name":"Chocobar","price":25,"quantity":14,"exp_date":"27-03-2027"},
          1160127:{"name":"Notebook","price":65,"quantity":11,"exp_date":"23-05-2024"},
          1160128:{"name":"book","price":450,"quantity":9,"exp_date":"24-03-2025"},
          1160129:{"name":"pencil","price":20,"quantity":9,"exp_date":"20-05-2026"},
          1160130:{"name":"pen","price":15,"quantity":8,"exp_date":"22-09-2026"},
          1160150:{"name":"jwelary","price":150000,"quantity":2,"exp_date":"22-09-2026"},
          1160151:{"name":"Ring","price":500,"quantity":8,"exp_date":"05-09-2026"},
          1160152:{"name":"Bottle","price":50,"quantity":10,"exp_date":"28-12-2026"},
          1160153:{"name":"Phone","price":5000,"quantity":7,"exp_date":"22-04-2026"},
          1160154:{"name":"Laptop","price":50000,"quantity":5,"exp_date":"29-09-2026"},
          1160155:{"name":"T.V","price":8000,"quantity":6,"exp_date":"30-09-2036"},
          1160156:{"name":"Fan","price":1000,"quantity":10,"exp_date":"20-09-3022"},
          1160157:{"name":"chain","price":1500,"quantity":10,"exp_date":"22-09-3026"},
          1160158:{"name":"pendrive","price":200,"quantity":5,"exp_date":"22-07-2025"},
          1160159:{"name":"cable","price":150,"quantity":20,"exp_date":"12-11-2026"},
          1160160:{"name":"Button","price":100,"quantity":10,"exp_date":"21-09-2026"},
          
         }

# %%
record
# Out:
# {1160111: {'name': 'Chocalate',
#   'price': 55,
#   'quantity': 500,
#   'exp_date': '22-05-2023'},
#  1160112: {'name': 'Maggiee',
#   'price': 60,
#   'quantity': 10,
#   'exp_date': '2012-2025'},
#  1160113: {'name': 'Coffee',
#   'price': 120,
#   'quantity': 5,
#   'exp_date': '22-08-2025'},
#  1160114: {'name': 'Sugar',
#   'price': 80,
#   'quantity': 6,
#   'exp_date': '2-07-2023'},
#  1160115: {'name': 'cadboury',
#   'price': 200,
#   'quantity': 20,
#   'exp_date': '22-05-2029'},
#  1160116: {'name': 'biscuit',
#   'price': 50,
#   'quantity': 10,
#   'exp_date': '11-09-2025'},
#  1160117: {'name': 'Water',
#   'price': 40,
#   'quantity': 15,
#   'exp_date': '16-05-2023'},
#  1160118: {'name': 'Colddrink',
#   'price': 75,
#   'quantity': 5,
#   'exp_date': '12-07-2026'},
#  1160119: {'name': 'Sanitizer',
#   'price': 110,
#   'quantity': 6,
#   'exp_date': '12-05-2030'},
#  1160120: {'name': 'Burger',
#   'price': 125,
#   'quantity': 8,
#   'exp_date': '30-10-2025'},
# ...

# %%
record[1160112]['quantity']=7

# %%
record
# Out:
# {1160111: {'name': 'Chocalate',
#   'price': 55,
#   'quantity': 500,
#   'exp_date': '22-05-2023'},
#  1160112: {'name': 'Maggiee',
#   'price': 60,
#   'quantity': 7,
#   'exp_date': '2012-2025'},
#  1160113: {'name': 'Coffee',
#   'price': 120,
#   'quantity': 5,
#   'exp_date': '22-08-2025'},
#  1160114: {'name': 'Sugar',
#   'price': 80,
#   'quantity': 6,
#   'exp_date': '2-07-2023'},
#  1160115: {'name': 'cadboury',
#   'price': 200,
#   'quantity': 20,
#   'exp_date': '22-05-2029'},
#  1160116: {'name': 'biscuit',
#   'price': 50,
#   'quantity': 10,
#   'exp_date': '11-09-2025'},
#  1160117: {'name': 'Water',
#   'price': 40,
#   'quantity': 15,
#   'exp_date': '16-05-2023'},
#  1160118: {'name': 'Colddrink',
#   'price': 75,
#   'quantity': 5,
#   'exp_date': '12-07-2026'},
#  1160119: {'name': 'Sanitizer',
#   'price': 110,
#   'quantity': 6,
#   'exp_date': '12-05-2030'},
#  1160120: {'name': 'Burger',
#   'price': 125,
#   'quantity': 8,
#   'exp_date': '30-10-2025'},
# ...

# %%
import json

# %%
js=json.dumps(record)

# %%
js
# Out:
# '{"1160111": {"name": "Chocalate", "price": 55, "quantity": 500, "exp_date": "22-05-2023"}, "1160112": {"name": "Maggiee", "price": 60, "quantity": 7, "exp_date": "2012-2025"}, "1160113": {"name": "Coffee", "price": 120, "quantity": 5, "exp_date": "22-08-2025"}, "1160114": {"name": "Sugar", "price": 80, "quantity": 6, "exp_date": "2-07-2023"}, "1160115": {"name": "cadboury", "price": 200, "quantity": 20, "exp_date": "22-05-2029"}, "1160116": {"name": "biscuit", "price": 50, "quantity": 10, "exp_date": "11-09-2025"}, "1160117": {"name": "Water", "price": 40, "quantity": 15, "exp_date": "16-05-2023"}, "1160118": {"name": "Colddrink", "price": 75, "quantity": 5, "exp_date": "12-07-2026"}, "1160119": {"name": "Sanitizer", "price": 110, "quantity": 6, "exp_date": "12-05-2030"}, "1160120": {"name": "Burger", "price": 125, "quantity": 8, "exp_date": "30-10-2025"}, "1160121": {"name": "Pizza", "price": 300, "quantity": 4, "exp_date": "19-05-2024"}, "1160122": {"name": "Tea", "price": 320, "q
# ...

# %%
record
# Out:
# {1160111: {'name': 'Chocalate',
#   'price': 55,
#   'quantity': 500,
#   'exp_date': '22-05-2023'},
#  1160112: {'name': 'Maggiee',
#   'price': 60,
#   'quantity': 7,
#   'exp_date': '2012-2025'},
#  1160113: {'name': 'Coffee',
#   'price': 120,
#   'quantity': 5,
#   'exp_date': '22-08-2025'},
#  1160114: {'name': 'Sugar',
#   'price': 80,
#   'quantity': 6,
#   'exp_date': '2-07-2023'},
#  1160115: {'name': 'cadboury',
#   'price': 200,
#   'quantity': 20,
#   'exp_date': '22-05-2029'},
#  1160116: {'name': 'biscuit',
#   'price': 50,
#   'quantity': 10,
#   'exp_date': '11-09-2025'},
#  1160117: {'name': 'Water',
#   'price': 40,
#   'quantity': 15,
#   'exp_date': '16-05-2023'},
#  1160118: {'name': 'Colddrink',
#   'price': 75,
#   'quantity': 5,
#   'exp_date': '12-07-2026'},
#  1160119: {'name': 'Sanitizer',
#   'price': 110,
#   'quantity': 6,
#   'exp_date': '12-05-2030'},
#  1160120: {'name': 'Burger',
#   'price': 125,
#   'quantity': 8,
#   'exp_date': '30-10-2025'},
# ...

# %%
fd=open("record.json",'w')
fd.write(js)
fd.close()

# %%
fd =open("record.json",'r')
txt=fd.read()
fd.close()

# %%
txt
# Out:
# '{"1160111": {"name": "Chocalate", "price": 55, "quantity": 500, "exp_date": "22-05-2023"}, "1160112": {"name": "Maggiee", "price": 60, "quantity": 7, "exp_date": "2012-2025"}, "1160113": {"name": "Coffee", "price": 120, "quantity": 5, "exp_date": "22-08-2025"}, "1160114": {"name": "Sugar", "price": 80, "quantity": 6, "exp_date": "2-07-2023"}, "1160115": {"name": "cadboury", "price": 200, "quantity": 20, "exp_date": "22-05-2029"}, "1160116": {"name": "biscuit", "price": 50, "quantity": 10, "exp_date": "11-09-2025"}, "1160117": {"name": "Water", "price": 40, "quantity": 15, "exp_date": "16-05-2023"}, "1160118": {"name": "Colddrink", "price": 75, "quantity": 5, "exp_date": "12-07-2026"}, "1160119": {"name": "Sanitizer", "price": 110, "quantity": 6, "exp_date": "12-05-2030"}, "1160120": {"name": "Burger", "price": 125, "quantity": 8, "exp_date": "30-10-2025"}, "1160121": {"name": "Pizza", "price": 300, "quantity": 4, "exp_date": "19-05-2024"}, "1160122": {"name": "Tea", "price": 320, "q
# ...

# %%
record=json.loads(txt)

# %%
fd=open("record.json",'r')
r=fd.read()
fd.close()
record=json.loads(r)

# %%
record
# Out:
# {'1160111': {'name': 'Chocalate',
#   'price': 55,
#   'quantity': 500,
#   'exp_date': '22-05-2023'},
#  '1160112': {'name': 'Maggiee',
#   'price': 60,
#   'quantity': 7,
#   'exp_date': '2012-2025'},
#  '1160113': {'name': 'Coffee',
#   'price': 120,
#   'quantity': 5,
#   'exp_date': '22-08-2025'},
#  '1160114': {'name': 'Sugar',
#   'price': 80,
#   'quantity': 6,
#   'exp_date': '2-07-2023'},
#  '1160115': {'name': 'cadboury',
#   'price': 200,
#   'quantity': 20,
#   'exp_date': '22-05-2029'},
#  '1160116': {'name': 'biscuit',
#   'price': 50,
#   'quantity': 10,
#   'exp_date': '11-09-2025'},
#  '1160117': {'name': 'Water',
#   'price': 40,
#   'quantity': 15,
#   'exp_date': '16-05-2023'},
#  '1160118': {'name': 'Colddrink',
#   'price': 75,
#   'quantity': 5,
#   'exp_date': '12-07-2026'},
#  '1160119': {'name': 'Sanitizer',
#   'price': 110,
#   'quantity': 6,
#   'exp_date': '12-05-2030'},
#  '1160120': {'name': 'Burger',
#   'price': 125,
#   'quantity': 8,
# ...

# %%
prod_id=str(input("Enter the product Id:"))
name=str(input("Enter the name:"))
price=int(input("Enter the price:"))
quantity=int(input("Enter the quantity:"))
exp_date=(input("Enter the exp_date"))
record[prod_id]={'name':name,'price':price,'quantity':quantity,'exp_date':exp_date}
js=json.dumps(record)
fd=open("record.json",'w')
fd.write(js)
fd.close()
# Out:
# Enter the product Id:1160167
# Enter the name:saree
# Enter the price:500
# Enter the quantity:5
# Enter the exp_date30-02-2028

# %%
record
# Out:
# {'1160111': {'name': 'Chocalate',
#   'price': 55,
#   'quantity': 500,
#   'exp_date': '22-05-2023'},
#  '1160112': {'name': 'Maggiee',
#   'price': 60,
#   'quantity': 7,
#   'exp_date': '2012-2025'},
#  '1160113': {'name': 'Coffee',
#   'price': 120,
#   'quantity': 5,
#   'exp_date': '22-08-2025'},
#  '1160114': {'name': 'Sugar',
#   'price': 80,
#   'quantity': 6,
#   'exp_date': '2-07-2023'},
#  '1160115': {'name': 'cadboury',
#   'price': 200,
#   'quantity': 20,
#   'exp_date': '22-05-2029'},
#  '1160116': {'name': 'biscuit',
#   'price': 50,
#   'quantity': 10,
#   'exp_date': '11-09-2025'},
#  '1160117': {'name': 'Water',
#   'price': 40,
#   'quantity': 15,
#   'exp_date': '16-05-2023'},
#  '1160118': {'name': 'Colddrink',
#   'price': 75,
#   'quantity': 5,
#   'exp_date': '12-07-2026'},
#  '1160119': {'name': 'Sanitizer',
#   'price': 110,
#   'quantity': 6,
#   'exp_date': '12-05-2030'},
#  '1160120': {'name': 'Burger',
#   'price': 125,
#   'quantity': 8,
# ...

# %%
ui_prod=str(input("Enter the product ID:"))
ui_quant=int(input("Enter the quantity:"))
print("product:",record[ui_prod]['name'])
print("price:",record[ui_prod]['price'])
print("Total Billing Amount:",record[ui_prod]['price'] * ui_quant)

record[ui_prod]['quantity'] = record[ui_prod]['quantity']-ui_quant
# Out:
# Enter the product ID:1160111
# Enter the quantity:4
# product: Chocalate
# price: 55
# Total Billing Amount: 220

# %%
js=json.dumps(record)
fd=open("record.json",'w')
fd.write(js)
fd.close()

# %%
record
# Out:
# {'1160111': {'name': 'Chocalate',
#   'price': 55,
#   'quantity': 496,
#   'exp_date': '22-05-2023'},
#  '1160112': {'name': 'Maggiee',
#   'price': 60,
#   'quantity': 7,
#   'exp_date': '2012-2025'},
#  '1160113': {'name': 'Coffee',
#   'price': 120,
#   'quantity': 5,
#   'exp_date': '22-08-2025'},
#  '1160114': {'name': 'Sugar',
#   'price': 80,
#   'quantity': 6,
#   'exp_date': '2-07-2023'},
#  '1160115': {'name': 'cadboury',
#   'price': 200,
#   'quantity': 20,
#   'exp_date': '22-05-2029'},
#  '1160116': {'name': 'biscuit',
#   'price': 50,
#   'quantity': 10,
#   'exp_date': '11-09-2025'},
#  '1160117': {'name': 'Water',
#   'price': 40,
#   'quantity': 15,
#   'exp_date': '16-05-2023'},
#  '1160118': {'name': 'Colddrink',
#   'price': 75,
#   'quantity': 5,
#   'exp_date': '12-07-2026'},
#  '1160119': {'name': 'Sanitizer',
#   'price': 110,
#   'quantity': 6,
#   'exp_date': '12-05-2030'},
#  '1160120': {'name': 'Burger',
#   'price': 125,
#   'quantity': 8,
# ...
